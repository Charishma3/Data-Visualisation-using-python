# %% [markdown]
# <h1>Data visualisation using python</h1>
# <p>Jalla Charishma</p>
# <p>Day 1 assignment</p>

# %% [markdown]
# <h1>QUESTION 1</h1>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.arange(0,11)
y=x*x
plt.title("Question 1 using Line plot",color="Black")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x,y,'r--')
plt.show()

# %% [markdown]
# <h1>Question 2</h1>

# %%
days = [1,2,3,4,5,6,7] #days of d week
sales_1 = [160,150,140,145,175,165,180] #sales of company1
sales_2 = [70,90,160,150,140,145,175]  #sales of company2
plt.title("Line plot",color="green")
plt.xlabel('days of week',color="green")
plt.ylabel('sales of company',color="green")
plt.plot(days,sales_1,"ro-")
plt.plot(days,sales_2,"y*-")

# %% [markdown]
# <h1>Question 3</h1>

# %%
x = [1,2,3,4]
y1 = [5,6,7,8]
y2 = [10,20,30,40]
y3 = [50,40,30,20]
y4 = [1,2,1,2]
y5 = [40,70,90,70]
plt.subplot(3,3,1)
plt.plot(x,y1,'go')
plt.subplot(3,3,2)
plt.plot(x,y2,'b*--')
plt.subplot(3,3,3)
plt.plot(x,y3,'r--')
plt.subplot(3,3,4)
plt.plot(x,y4,'y<-')
plt.subplot(3,3,5)
plt.plot(x,y5,"b>-")
